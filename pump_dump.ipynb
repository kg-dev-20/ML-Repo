# %% [markdown]
# <a href="https://colab.research.google.com/github/kg-dev-20/ML-Repo/blob/main/pump_dump.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df =pd.read_csv('/content/drive/MyDrive/ETH_1H.csv')
df
# Out:
# Mounted at /content/drive
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34497 entries, 0 to 34496
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unix Timestamp  34497 non-null  int64
#  1   Date            34497 non-null  object
#  2   Symbol          34497 non-null  object
#  3   Open            34497 non-null  float64
#  4   High            34497 non-null  float64
#  5   Low             34497 non-null  float64
#  6   Close           34497 non-null  float64
#  7   Volume          34497 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.1+ MB

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.corr(numeric_only=True)
# Out:
#                 Unix Timestamp      Open      High       Low     Close  \
# Unix Timestamp        1.000000 -0.148268 -0.149557 -0.146748 -0.148357
# Open                 -0.148268  1.000000  0.999868  0.999809  0.999772
# High                 -0.149557  0.999868  1.000000  0.999705  0.999875
# Low                  -0.146748  0.999809  0.999705  1.000000  0.999839
# Close                -0.148357  0.999772  0.999875  0.999839  1.000000
# Volume               -0.079237  0.064437  0.066342  0.061687  0.064271
#
#                   Volume
# Unix Timestamp -0.079237
# Open            0.064437
# High            0.066342
# Low             0.061687
# Close           0.064271
# Volume          1.000000

# %%
df=df.sort_values('Date')
df.set_index('Date',inplace=True)
df
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2016-05-09 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
# 2016-05-09 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-05-09 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-05-09 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-05-09 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# ...                             ...     ...     ...     ...     ...     ...
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
#
#                           Volume
# Date
# ...

# %%
df=df.drop(['Symbol'],axis=1)
df
# Out:
#                      Unix Timestamp    Open    High     Low   Close  \
# Date
# 2016-05-09 13:00:00      1462798800    0.00   12.00    0.00    9.55
# 2016-05-09 14:00:00      1462802400    9.55   10.00    9.55   10.00
# 2016-05-09 15:00:00      1462806000   10.00   10.00    9.99    9.99
# 2016-05-09 16:00:00      1462809600    9.99    9.99    9.79    9.83
# 2016-05-09 17:00:00      1462813200    9.83    9.83    9.48    9.49
# ...                             ...     ...     ...     ...     ...
# 2020-04-15 20:00:00   1586980800000  157.10  158.10  156.87  158.04
# 2020-04-15 21:00:00   1586984400000  158.04  158.31  157.16  157.18
# 2020-04-15 22:00:00   1586988000000  157.18  157.30  155.32  155.81
# 2020-04-15 23:00:00   1586991600000  155.81  155.81  151.39  152.94
# 2020-04-16 00:00:00   1586995200000  152.94  152.94  150.39  150.39
#
#                           Volume
# Date
# 2016-05-09 13:00:00   432.562115
# 2016-05-09 14:00:00   235.774075
# 2016-05-09 15:00:00    10.973567
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(df['Volume'])
# Out:
# <Axes: ylabel='Volume'>

# %%
df['Volume'].max()
# Out:
# 903102.6857

# %%
df['Volume'].mean()
# Out:
# np.float64(1563.62547113705)

# %%
df=df.drop(['Unix Timestamp'],axis=1)
df
# Out:
#                        Open    High     Low   Close       Volume
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213
# ...                     ...     ...     ...     ...          ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125
#
# [34497 rows x 5 columns]

# %%
sns.distplot(df['Volume'])
# Out:
# /tmp/ipython-input-205/253520841.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Volume'])
# <Axes: xlabel='Volume', ylabel='Density'>

# %%
df['Return']=df['Close'].pct_change()*100
df
# Out:
#                        Open    High     Low   Close       Volume    Return
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115       NaN
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075  4.712042
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567 -0.100000
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450 -1.601602
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213 -3.458800
# ...                     ...     ...     ...     ...          ...       ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622  0.598345
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131 -0.544166
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279 -0.871612
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299 -1.841987
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125 -1.667321
#
# [34497 rows x 6 columns]

# %%
df['Return'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Volatility'] = df['Return'].rolling(window=24).std()
df
# Out:
#                        Open    High     Low   Close       Volume    Return  \
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115       NaN
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075  4.712042
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567 -0.100000
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450 -1.601602
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213 -3.458800
# ...                     ...     ...     ...     ...          ...       ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622  0.598345
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131 -0.544166
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279 -0.871612
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299 -1.841987
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125 -1.667321
#
#                      Volatility
# Date
# ...

# %%
df['Volatility'] = df['Return'].rolling(window=24).std()
df['Volume_Change'] = df['Volume'].pct_change()
df['Rolling_Mean'] = df['Close'].rolling(window=24).mean() #mean with past 24hours ka data bcuz window = 24
df['Rolling_Std']  = df['Close'].rolling(window=24).std() # std deviation of past 24 hours


df
# Out:
#                        Open    High     Low   Close       Volume    Return  \
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115       NaN
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075  4.712042
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567 -0.100000
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450 -1.601602
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213 -3.458800
# ...                     ...     ...     ...     ...          ...       ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622  0.598345
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131 -0.544166
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279 -0.871612
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299 -1.841987
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125 -1.667321
#
# ...

# %%
plt.scatter(df['Volume_Change'],df['Return'])

# %%
features=['Return','Volatility','Volume_Change','Rolling_Mean','Rolling_Std']
df[features] = df[features].fillna(0)

# %%
df
# Out:
#                        Open    High     Low   Close       Volume    Return  \
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115  0.000000
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075  4.712042
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567 -0.100000
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450 -1.601602
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213 -3.458800
# ...                     ...     ...     ...     ...          ...       ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622  0.598345
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131 -0.544166
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279 -0.871612
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299 -1.841987
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125 -1.667321
#
# ...

# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
X = df[features].values
model = IsolationForest(n_estimators=200, contamination=0.02, random_state=42)
df['anomaly'] = model.fit_predict(X)
df['anomaly'] = df['anomaly'].map({1:0, -1:1})  #0 matlab normal trading 1 matlab possible pump and dump
df['anomaly'].value_counts()
# Out:
# anomaly
# 0    33807
# 1      690
# Name: count, dtype: int64

# %%
df
# Out:
#                        Open    High     Low   Close       Volume    Return  \
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115  0.000000
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075  4.712042
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567 -0.100000
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450 -1.601602
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213 -3.458800
# ...                     ...     ...     ...     ...          ...       ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622  0.598345
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131 -0.544166
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279 -0.871612
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299 -1.841987
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125 -1.667321
#
# ...

# %%
df_anomaly = df[df['anomaly']==1]
df_anomaly
# Out:
#                        Open    High     Low   Close        Volume     Return  \
# Date
# 2016-05-12 20:00:00   10.30   10.30   10.30   10.30      0.000000   0.000000
# 2016-05-13 11:00:00   11.59   11.59   11.59   11.59      0.000000   0.000000
# 2016-05-14 01:00:00   10.98   10.98   10.98   10.98      0.000000   0.000000
# 2016-05-14 05:00:00   10.35   10.35   10.35   10.35      0.000000   0.000000
# 2016-06-17 16:00:00   16.76   16.95   14.43   14.76   2523.425409 -11.933174
# ...                     ...     ...     ...     ...           ...        ...
# 2020-03-13 11:00:00  132.52  133.00  125.84  129.23   3494.365210  -2.482644
# 2020-03-13 14:00:00  134.47  138.74  126.36  128.43   5531.873343  -4.491708
# 2020-03-13 15:00:00  128.43  129.49  116.52  124.77  10899.085189  -2.849801
# 2020-03-13 18:00:00  124.41  124.63  115.70  119.72   8758.703833  -3.769793
# 2020-03-13 19:00:00  119.72  131.95  117.38  129.23   7998.114135   7.943535
#
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(df.index, df['Close'], label="ETH Close Price", alpha=0.7)
plt.scatter(df.index[df['anomaly']==1], df['Close'][df['anomaly']==1],
            color='red', label="Pump/Dump Signal", s=30)
plt.title("Ethereum Pump & Dump Detection (Isolation Forest)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()

# %%
df
# Out:
#                        Open    High     Low   Close       Volume    Return  \
# Date
# 2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115  0.000000
# 2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075  4.712042
# 2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567 -0.100000
# 2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450 -1.601602
# 2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213 -3.458800
# ...                     ...     ...     ...     ...          ...       ...
# 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622  0.598345
# 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131 -0.544166
# 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279 -0.871612
# 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299 -1.841987
# 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125 -1.667321
#
# ...

# %%
new_df = df.reset_index()  # Moves the index (Date) into a column
new_df
# Out:
#                      Date    Open    High     Low   Close       Volume  \
# 0     2016-05-09 13:00:00    0.00   12.00    0.00    9.55   432.562115
# 1     2016-05-09 14:00:00    9.55   10.00    9.55   10.00   235.774075
# 2     2016-05-09 15:00:00   10.00   10.00    9.99    9.99    10.973567
# 3     2016-05-09 16:00:00    9.99    9.99    9.79    9.83    62.379450
# 4     2016-05-09 17:00:00    9.83    9.83    9.48    9.49   329.553213
# ...                   ...     ...     ...     ...     ...          ...
# 34492 2020-04-15 20:00:00  157.10  158.10  156.87  158.04   144.262622
# 34493 2020-04-15 21:00:00  158.04  158.31  157.16  157.18    55.244131
# 34494 2020-04-15 22:00:00  157.18  157.30  155.32  155.81   106.337279
# 34495 2020-04-15 23:00:00  155.81  155.81  151.39  152.94  4277.567299
# 34496 2020-04-16 00:00:00  152.94  152.94  150.39  150.39   650.188125
#
#          Return  Volatility  Volume_Change  Rolling_Mean  Rolling_Std  anomaly
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))
plt.plot(anomaly_counts.index, anomaly_counts.values, marker='o', linestyle='-')
plt.title("Daily Anomaly Counts")
plt.xlabel("Date")
plt.ylabel("Number of Anomalies")
plt.xticks(rotation=45)  # rotate date labels
plt.grid(True)
plt.show()

# %% [markdown]
# In 2018, the cryptocurrency market, including Ethereum and numerous ERC-20 tokens, experienced widespread "pump and dump" schemes. Organized largely on Telegram and Discord, these scams involved inflating token prices through coordinated buying before dumping them, often resulting in significant losses for late investors and high volatility for smaller Ethereum-based projects.
# RePEc: Research Papers in Economics
# RePEc: Research Papers in Economics
#  +4
# Key Aspects of the 2018 Ethereum Pump-and-Dump Era:
# Mechanism: Organizers on encrypted messaging apps would select a "coin of the day," often an obscure token with low market cap, inducing a rapid price spike.
# Scale: Studies identified over 3,700 different pump signals on Telegram and over 1,000 on Discord during a six-month period in 2018.
# Targeted Tokens: While Ether itself was rarely the sole target of these small-scale, rapid-fire schemes, many ERC-20 tokens built on Ethereum were targeted due to ease of trading on decentralized exchanges.
# Regulation: The CFTC issued warnings in early 2018 regarding these schemes, noting limited authority over such markets at the time.
# Market Impact: These activities contributed to extreme, short-term price distortions, often averaging over 65% for the targeted tokens.
